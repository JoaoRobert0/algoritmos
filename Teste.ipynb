# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoRobert0/Algoritmos/blob/main/Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
cv2.__version__

image = cv2.imread('helena.png', cv2.IMREAD_GRAYSCALE)
print(image)
print(2)

plt.imshow(image, cmap='gray')
# Out:
# [[ 69  69  69 ...  69  69  69]
#  [209 209 206 ... 191 190  14]
#  [207 207 206 ... 191 190  14]
#  ...
#  [ 99 107 113 ...  94 104  14]
#  [106 111 110 ...  95  96  14]
#  [111 109 102 ...  90  89  14]]
# 2
